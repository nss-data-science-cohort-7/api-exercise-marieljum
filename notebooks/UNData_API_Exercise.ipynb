# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# 1. Use the API to get all available data for the _GDP per capita, PPP (constant 2017 international $)_ indicator. Hint: this indicator has code "NY.GDP.PCAP.PP.KD". Adjust the query parameters so that you can retrieve all available rows. Convert the results to a DataFrame.

# %%
endpoint = 'http://api.worldbank.org/v2/country/all/indicator/NY.GDP.PCAP.PP.KD?format=json'

response = requests.get(endpoint)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '[{"page":1,"pages":336,"per_page":50,"total":16758,"sourceid":"2","lastupdated":"2023-09-19"},[{"indicator":{"id":"NY.GDP.PCAP.PP.KD","value":"GDP per capita, PPP (constant 2017 international $)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2022","value":3553.91337005893,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.PCAP.PP.KD","value":"GDP per capita, PPP (constant 2017 international $)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2021","value":3519.17483992362,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.PCAP.PP.KD","value":"GDP per capita, PPP (constant 2017 international $)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2020","value":3455.02311899819,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.PCAP.PP.KD","value":"GDP per capita, PPP (constant 2017 international $)"},"country
# ...

# %%
res = response.json()
res
# Out:
# [{'page': 1,
#   'pages': 336,
#   'per_page': 50,
#   'total': 16758,
#   'sourceid': '2',
#   'lastupdated': '2023-09-19'},
#  [{'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2022',
#    'value': 3553.91337005893,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2021',
#    'value': 3519.17483992362,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
# ...

# %%
res[1]
# Out:
# [{'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2017 international $)'},
#   'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#   'countryiso3code': 'AFE',
#   'date': '2022',
#   'value': 3553.91337005893,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2017 international $)'},
#   'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#   'countryiso3code': 'AFE',
#   'date': '2021',
#   'value': 3519.17483992362,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#    'value': 'GDP per capita, PPP (constant 2017 international $)'},
#   'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#   'countryiso3code': 'AFE',
#   'date': '2020',
#   'value': 3455.02311899819,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
# ...

# %%
GDP_per_cap = pd.DataFrame(res[1])
print(GDP_per_cap)
# Out:
#                                             indicator  \
# 0   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 1   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 2   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 3   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 4   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 5   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 6   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 7   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 8   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 9   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 10  {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 11  {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 12  {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 13  {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 14  {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 15  {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# ...

# %%
GDP_per_cap.keys()
# Out:
# Index(['indicator', 'country', 'countryiso3code', 'date', 'value', 'unit',
#        'obs_status', 'decimal'],
#       dtype='object')

# %%
GDP_per_cap['indicator']
# Out:
# 0     {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 1     {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 2     {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 3     {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 4     {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 5     {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 6     {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 7     {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 8     {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 9     {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 10    {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 11    {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 12    {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 13    {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 14    {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 15    {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 16    {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# ...

# %%
GDP_per_cap['indicator'][0].keys()
# Out:
# dict_keys(['id', 'value'])

# %%
GDP_per_cap['country'][0].keys()
# Out:
# dict_keys(['id', 'value'])

# %%
GDP_per_cap['countryiso3code']
# Out:
# 0     AFE
# 1     AFE
# 2     AFE
# 3     AFE
# 4     AFE
# 5     AFE
# 6     AFE
# 7     AFE
# 8     AFE
# 9     AFE
# 10    AFE
# 11    AFE
# 12    AFE
# 13    AFE
# 14    AFE
# 15    AFE
# 16    AFE
# 17    AFE
# 18    AFE
# 19    AFE
# 20    AFE
# 21    AFE
# 22    AFE
# 23    AFE
# 24    AFE
# 25    AFE
# 26    AFE
# 27    AFE
# 28    AFE
# 29    AFE
# 30    AFE
# 31    AFE
# 32    AFE
# 33    AFE
# 34    AFE
# 35    AFE
# 36    AFE
# 37    AFE
# 38    AFE
# 39    AFE
# 40    AFE
# 41    AFE
# 42    AFE
# 43    AFE
# 44    AFE
# 45    AFE
# 46    AFE
# 47    AFE
# 48    AFE
# 49    AFE
# Name: countryiso3code, dtype: object

# %%
GDP_per_cap = pd.json_normalize(GDP_per_cap['indicator'])
print(GDP_per_cap)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'indicator'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
